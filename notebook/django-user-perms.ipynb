# %%
import setup
setup.init()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import setup
# ----> 2 setup.init()
#
# File e:\ai agent + backend\notebook\setup.py:23, in init(verbose)
#      20     if verbose:
#      21         print("nest_asyncio not available, skipping patch")
# ---> 23 os.chdir(DJANGO_PROJECT_ROOT)
#      24 sys.path.insert(0, str(DJANGO_PROJECT_ROOT))
#      25 if verbose:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'e:\\ai agent + backend\\src'

# %%
from django.contrib.auth import get_user_model

User = get_user_model()

User.objects.all()
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# Cell In[2], line 3
#       1 from django.contrib.auth import get_user_model
#       2
# ----> 3 User = get_user_model()
#       4
#       5 User.objects.all()
#
# File e:\ai agent + backend\venv\Lib\site-packages\django\contrib\auth\__init__.py:266, in get_user_model()
#     262 """
#     263 Return the User model that is active in this project.
#     264 """
#     265 try:
# --> 266     return django_apps.get_model(settings.AUTH_USER_MODEL, require_ready=False)
#     267 except ValueError:
#     268     raise ImproperlyConfigured(
#     269         "AUTH_USER_MODEL must be of the form 'app_label.model_name'"
#     270     )
#
# File e:\ai agent + backend\venv\Lib\site-packages\django\conf\__init__.py:122, in LazySettings.__getattr__(self, name)
#     120 """Return the value of a setting and cache it in self.__dict__."""
# ...

# %%
user_obj = User(
    username = "fdsagdf"
)
user_obj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 user_obj = User(
#       2     username = "ghf"
#       3 )
#       4 user_obj
#
# NameError: name 'User' is not defined

# %%
user_obj.save()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 user_obj.save()
#
# NameError: name 'user_obj' is not defined

# %%
from documents.models import Document

doc_obj = Document(
    owner = user_obj,
    title = "ai blog" ,
    content = "Fascinating AI FactsAncient Origins: ",
    active = "True"    
)
doc_obj
# Out:
# <Document: Document object (None)>

# %%
doc_obj.save()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 doc_obj.save()
#
# NameError: name 'doc_obj' is not defined
